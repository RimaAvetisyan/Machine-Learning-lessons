# %%
import pandas as pd
full_df = pd.read_csv('training_data.csv')

# %%
full_df.shape
# Out:
# (25079, 18)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(full_df.drop('Survived_1_year', axis=1), full_df['Survived_1_year'], test_size=0.1, random_state=42)

# %%
full_df.head()
# Out:
#    ID_Patient_Care_Situation  Diagnosed_Condition  Patient_ID  \
# 0                      16201                   47        8433
# 1                       9421                    3        2972
# 2                      16205                    7        8608
# 3                       5582                   31       10074
# 4                      20880                   43        7462
#
#   Treated_with_drugs  Patient_Age  Patient_Body_Mass_Index Patient_Smoker  \
# 0                DX2           60                21.655523             NO
# 1                DX6            2                28.852743             NO
# 2                Dx6           20                26.179725             NO
# 3               dx6             8                22.638945             NO
# 4                dx1           53                21.326131             NO
#
#   Patient_Rural_Urban Patient_mental_condition    A    B    C    D    E    F  \
# ...

# %%
X_train.head()
# Out:
#        ID_Patient_Care_Situation  Diagnosed_Condition  Patient_ID  \
# 7163                       26082                   19        3525
# 17539                       3935                    2       11357
# 10902                      25150                   45       10831
# 15014                       6843                   16        3726
# 18104                      30965                   30        3903
#
#       Treated_with_drugs  Patient_Age  Patient_Body_Mass_Index Patient_Smoker  \
# 7163             DX3 DX4           49                18.996774            YES
# 17539            dx1 dx4           32                18.807999            YES
# 10902               DX6            43                26.737058            NO
# 15014                dx6            9                21.950668             NO
# 18104            DX3 DX4           44                20.591655            YES
#
#       Patient_Rural_Urban Patient_mental_condition    A    B    C    D    E  \
# ...

# %%
train = X_train.copy()

# %%
train['Survived_1_year'] = y_train

# %%
train
# Out:
#        ID_Patient_Care_Situation  Diagnosed_Condition  Patient_ID  \
# 7163                       26082                   19        3525
# 17539                       3935                    2       11357
# 10902                      25150                   45       10831
# 15014                       6843                   16        3726
# 18104                      30965                   30        3903
# ...                          ...                  ...         ...
# 21575                      11752                   42        7540
# 5390                       32797                   52        1337
# 860                        10129                   44        5506
# 15795                       5831                   11       10850
# 23654                      12106                   50        2667
#
#       Treated_with_drugs  Patient_Age  Patient_Body_Mass_Index Patient_Smoker  \
# 7163             DX3 DX4           49                18.996774            YES
# ...

# %%
train.to_csv('hospital_train.csv', index=False)

# %%
X_test.to_csv('hospital_test_X.csv', index=False)

# %%
y_test.to_csv('y_test.csv', index=False)

# %%
y_test.iloc[:] = 0

# %%
y_test
# Out:
# 18217    0
# 11458    0
# 10948    0
# 24832    0
# 20624    0
#         ..
# 5505     0
# 1527     0
# 6619     0
# 16860    0
# 2727     0
# Name: Survived_1_year, Length: 2508, dtype: int64

# %%
y_test.to_csv('predictions.csv', index=False)

# %%
full_df['Treated_with_drugs'][129]
# Out:
# 'DX4 DX5 '

# %%
X_test
# Out:
#        ID_Patient_Care_Situation  Diagnosed_Condition  Patient_ID  \
# 18217                       3717                   45        2776
# 11458                       9298                   18         834
# 10948                      17917                   29        8234
# 24832                       5626                   52        5047
# 20624                        307                   19        4303
# ...                          ...                  ...         ...
# 5505                       19823                   36        5653
# 1527                       22371                   34         250
# 6619                       19201                    8        2499
# 16860                        487                   26        3323
# 2727                       27637                   35         461
#
#       Treated_with_drugs  Patient_Age  Patient_Body_Mass_Index Patient_Smoker  \
# 18217               Dx6            35                23.775226           YES
# ...

# %%
X_train['Treated_with_drugs'][1527]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\users\default.laptop-meq8135q\pycharmprojects\pythonproject1\venv\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 1527
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
X_train.iloc[20]
# Out:
# ID_Patient_Care_Situation      21400
# Diagnosed_Condition               19
# Patient_ID                      2201
# Treated_with_drugs           DX1 DX3
# Patient_Age                       14
# Patient_Body_Mass_Index      24.2264
# Patient_Smoker                   YES
# Patient_Rural_Urban            URBAN
# Patient_mental_condition      Stable
# A                                  0
# B                                  0
# C                                  0
# D                                  0
# E                                  1
# F                                  0
# Z                                  0
# Number_of_prev_cond                1
# Name: 22276, dtype: object

# %%
X_train['Treated_with_drugs'].values[1527]
# Out:
# 'dx2'

# %%
X_train.iloc[1527]['Treated_with_drugs']
# Out:
# 'dx2'

# %%
X_train.loc[15]
# Out:
# ID_Patient_Care_Situation      20639
# Diagnosed_Condition                2
# Patient_ID                      5363
# Treated_with_drugs           DX3 DX5
# Patient_Age                       39
# Patient_Body_Mass_Index       20.848
# Patient_Smoker                   YES
# Patient_Rural_Urban            RURAL
# Patient_mental_condition      Stable
# A                                  1
# B                                  0
# C                                  0
# D                                  0
# E                                  1
# F                                  0
# Z                                  0
# Number_of_prev_cond                2
# Name: 15, dtype: object

# %%
X_test[X_test['A'].isna()]
# Out:
#        ID_Patient_Care_Situation  Diagnosed_Condition  Patient_ID  \
# 8583                        6828                    8       11170
# 11433                      23179                   23       12106
# 21697                      27069                   31        7796
# 19434                      11912                   47        1104
# 10533                      16833                   20        3456
# ...                          ...                  ...         ...
# 24549                      28165                   25        7954
# 12920                      21456                   45        4265
# 16342                        964                   44       10736
# 6906                        6064                    7        2044
# 16860                        487                   26        3323
#
#       Treated_with_drugs  Patient_Age  Patient_Body_Mass_Index Patient_Smoker  \
# 8583                 DX6           48                22.937588            YES
# ...
